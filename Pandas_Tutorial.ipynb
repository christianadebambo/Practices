# %%
import pandas as pd
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-64330f34-692e-4ef0-b9b5-717550285376" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64330f34-692e-4ef0-b9b5-717550285376">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sales.csv to sales.csv

# %%
import io
sales_df = pd.read_csv(io.BytesIO(data_to_load['sales.csv']))
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
sales_df.head()
# Out:
#        ORDER_ID   TIMESTAMP   USER_ID        ITEM_ID           LOCATION  \
# 0   99520090990  1644868800   GR10015  GFI081434198I  VSV RIVIERE NOIRE
# 1  999780046317  1645819200  GR100607  GFI307337001J  VSV PHOENIX JUMBO
# 2  999780046317  1645819200  GR100607  GFI172185001L  VSV PHOENIX JUMBO
# 3  999780046317  1645819200  GR100607  GFI086772002K  VSV PHOENIX JUMBO
# 4  999780046514  1646424000  GR100611  GFI172668001J  VSV PHOENIX JUMBO
#
#   EVENT_TYPE  EVENT_VALUE
# 0  PURCHASED          1.0
# 1  PURCHASED          1.0
# 2  PURCHASED          1.0
# 3  PURCHASED          1.0
# 4  PURCHASED          1.0

# %%
sales_df.shape
# Out:
# (154247, 7)

# %%
sales_df.columns
# Out:
# Index(['ORDER_ID', 'TIMESTAMP', 'USER_ID', 'ITEM_ID', 'LOCATION', 'EVENT_TYPE',
#        'EVENT_VALUE'],
#       dtype='object')

# %%
sales_df['USER_ID']
# Out:
# 0          GR10015
# 1         GR100607
# 2         GR100607
# 3         GR100607
# 4         GR100611
#             ...
# 154242     GR99590
# 154243     GR99590
# 154244     GR99590
# 154245     GR99590
# 154246     GR99602
# Name: USER_ID, Length: 154247, dtype: object

# %%
sales_df.loc[0:10, 'ORDER_ID':'USER_ID']
# Out:
#         ORDER_ID   TIMESTAMP   USER_ID
# 0    99520090990  1644868800   GR10015
# 1   999780046317  1645819200  GR100607
# 2   999780046317  1645819200  GR100607
# 3   999780046317  1645819200  GR100607
# 4   999780046514  1646424000  GR100611
# 5   IVVFQ0003029  1645732800   GR10062
# 6     9022010267  1645732800   GR10068
# 7     9022010375  1646078400   GR10068
# 8   IVVGB0006027  1646337600   GR10069
# 9   IVVLC0004338  1644868800   GR10069
# 10  IVVLC0004358  1644955200  GR101565

# %%
type(sales_df['USER_ID'])
# Out:
# pandas.core.series.Series

# %%
sales_df[['USER_ID', 'ITEM_ID']]
# Out:
#          USER_ID        ITEM_ID
# 0        GR10015  GFI081434198I
# 1       GR100607  GFI307337001J
# 2       GR100607  GFI172185001L
# 3       GR100607  GFI086772002K
# 4       GR100611  GFI172668001J
# ...          ...            ...
# 154242   GR99590  GFI038077002L
# 154243   GR99590  GFI172683001J
# 154244   GR99590  GFI153263002I
# 154245   GR99590  GFI153263022I
# 154246   GR99602  GFI081707003I
#
# [154247 rows x 2 columns]

# %%
sales_df.sort_index(inplace=True)
sales_df
# Out:
#             ORDER_ID   TIMESTAMP   USER_ID        ITEM_ID           LOCATION  \
# 0        99520090990  1644868800   GR10015  GFI081434198I  VSV RIVIERE NOIRE
# 1       999780046317  1645819200  GR100607  GFI307337001J  VSV PHOENIX JUMBO
# 2       999780046317  1645819200  GR100607  GFI172185001L  VSV PHOENIX JUMBO
# 3       999780046317  1645819200  GR100607  GFI086772002K  VSV PHOENIX JUMBO
# 4       999780046514  1646424000  GR100611  GFI172668001J  VSV PHOENIX JUMBO
# ...              ...         ...       ...            ...                ...
# 154242   99510083850  1642795200   GR99590  GFI038077002L        VSV FLOREAL
# 154243   99510083850  1642795200   GR99590  GFI172683001J        VSV FLOREAL
# 154244   99510083850  1642795200   GR99590  GFI153263002I        VSV FLOREAL
# 154245   99510083850  1642795200   GR99590  GFI153263022I        VSV FLOREAL
# 154246  999780045457  1642795200   GR99602  GFI081707003I  VSV PHOENIX JUMBO
#
#        EVENT_TYPE  EVENT_VALUE
# ...

# %%
sales_df.set_index('USER_ID', inplace=True)
sales_df
# Out:
#               ORDER_ID   TIMESTAMP        ITEM_ID           LOCATION  \
# USER_ID
# GR10015    99520090990  1644868800  GFI081434198I  VSV RIVIERE NOIRE
# GR100607  999780046317  1645819200  GFI307337001J  VSV PHOENIX JUMBO
# GR100607  999780046317  1645819200  GFI172185001L  VSV PHOENIX JUMBO
# GR100607  999780046317  1645819200  GFI086772002K  VSV PHOENIX JUMBO
# GR100611  999780046514  1646424000  GFI172668001J  VSV PHOENIX JUMBO
# ...                ...         ...            ...                ...
# GR99590    99510083850  1642795200  GFI038077002L        VSV FLOREAL
# GR99590    99510083850  1642795200  GFI172683001J        VSV FLOREAL
# GR99590    99510083850  1642795200  GFI153263002I        VSV FLOREAL
# GR99590    99510083850  1642795200  GFI153263022I        VSV FLOREAL
# GR99602   999780045457  1642795200  GFI081707003I  VSV PHOENIX JUMBO
#
#          EVENT_TYPE  EVENT_VALUE
# USER_ID
# GR10015   PURCHASED          1.0
# GR100607  PURCHASED          1.0
# ...

# %%
sales_df.reset_index(inplace=True)

# %%
sales_df
# Out:
#          USER_ID      ORDER_ID   TIMESTAMP        ITEM_ID           LOCATION  \
# 0        GR10015   99520090990  1644868800  GFI081434198I  VSV RIVIERE NOIRE
# 1       GR100607  999780046317  1645819200  GFI307337001J  VSV PHOENIX JUMBO
# 2       GR100607  999780046317  1645819200  GFI172185001L  VSV PHOENIX JUMBO
# 3       GR100607  999780046317  1645819200  GFI086772002K  VSV PHOENIX JUMBO
# 4       GR100611  999780046514  1646424000  GFI172668001J  VSV PHOENIX JUMBO
# ...          ...           ...         ...            ...                ...
# 154242   GR99590   99510083850  1642795200  GFI038077002L        VSV FLOREAL
# 154243   GR99590   99510083850  1642795200  GFI172683001J        VSV FLOREAL
# 154244   GR99590   99510083850  1642795200  GFI153263002I        VSV FLOREAL
# 154245   GR99590   99510083850  1642795200  GFI153263022I        VSV FLOREAL
# 154246   GR99602  999780045457  1642795200  GFI081707003I  VSV PHOENIX JUMBO
#
#        EVENT_TYPE  EVENT_VALUE
# ...

# %%
filt = (sales_df['LOCATION'] == 'VSV FLOREAL')

# %%
sales_df[filt]
# Out:
#          USER_ID      ORDER_ID   TIMESTAMP        ITEM_ID     LOCATION  \
# 39      GR101955  IVVFL0000737  1645646400  GFI081004030I  VSV FLOREAL
# 40      GR101955  IVVFL0000737  1645646400  GFI086772002K  VSV FLOREAL
# 74      GR102266  IVVFL0000887  1646424000  GFI172037022J  VSV FLOREAL
# 90      GR102442  IVVFL0000664  1645128000  GFI156613001I  VSV FLOREAL
# 152     GR102825   99510084127  1644436800  GFI172011002J  VSV FLOREAL
# ...          ...           ...         ...            ...          ...
# 154236   GR96669   99510083800  1642622400  GFI286260002I  VSV FLOREAL
# 154242   GR99590   99510083850  1642795200  GFI038077002L  VSV FLOREAL
# 154243   GR99590   99510083850  1642795200  GFI172683001J  VSV FLOREAL
# 154244   GR99590   99510083850  1642795200  GFI153263002I  VSV FLOREAL
# 154245   GR99590   99510083850  1642795200  GFI153263022I  VSV FLOREAL
#
#        EVENT_TYPE  EVENT_VALUE
# 39      PURCHASED         12.0
# 40      PURCHASED          4.0
# ...

# %%
filt = sales_df['LOCATION'].str.contains('PHOENIX', na=False)
sales_df.loc[filt, 'LOCATION']
# Out:
# 1         VSV PHOENIX JUMBO
# 2         VSV PHOENIX JUMBO
# 3         VSV PHOENIX JUMBO
# 4         VSV PHOENIX JUMBO
# 17        VSV PHOENIX JUMBO
#                 ...
# 154196    VSV PHOENIX JUMBO
# 154197    VSV PHOENIX JUMBO
# 154203    VSV PHOENIX JUMBO
# 154204    VSV PHOENIX JUMBO
# 154246    VSV PHOENIX JUMBO
# Name: LOCATION, Length: 14506, dtype: object

# %%
sales_df['EVENT_TYPE'] = sales_df['EVENT_TYPE'].map({'PURCHASED': 'BOUGHT'})

# %%
sales_df['EVENT_TYPE']
# Out:
# 0         BOUGHT
# 1         BOUGHT
# 2         BOUGHT
# 3         BOUGHT
# 4         BOUGHT
#            ...
# 154242    BOUGHT
# 154243    BOUGHT
# 154244    BOUGHT
# 154245    BOUGHT
# 154246    BOUGHT
# Name: EVENT_TYPE, Length: 154247, dtype: object

# %%
sales_df['EVENT_TYPE'] = sales_df['EVENT_TYPE'].str.lower()
sales_df
# Out:
#          USER_ID      ORDER_ID   TIMESTAMP        ITEM_ID           LOCATION  \
# 0        GR10015   99520090990  1644868800  GFI081434198I  VSV RIVIERE NOIRE
# 1       GR100607  999780046317  1645819200  GFI307337001J  VSV PHOENIX JUMBO
# 2       GR100607  999780046317  1645819200  GFI172185001L  VSV PHOENIX JUMBO
# 3       GR100607  999780046317  1645819200  GFI086772002K  VSV PHOENIX JUMBO
# 4       GR100611  999780046514  1646424000  GFI172668001J  VSV PHOENIX JUMBO
# ...          ...           ...         ...            ...                ...
# 154242   GR99590   99510083850  1642795200  GFI038077002L        VSV FLOREAL
# 154243   GR99590   99510083850  1642795200  GFI172683001J        VSV FLOREAL
# 154244   GR99590   99510083850  1642795200  GFI153263002I        VSV FLOREAL
# 154245   GR99590   99510083850  1642795200  GFI153263022I        VSV FLOREAL
# 154246   GR99602  999780045457  1642795200  GFI081707003I  VSV PHOENIX JUMBO
#
#        EVENT_TYPE  EVENT_VALUE
# ...

# %%
sales_df['LOCATION'].str.split(' ', expand=True)
# Out:
#           0        1      2     3     4     5
# 0       VSV  RIVIERE  NOIRE  None  None  None
# 1       VSV  PHOENIX  JUMBO  None  None  None
# 2       VSV  PHOENIX  JUMBO  None  None  None
# 3       VSV  PHOENIX  JUMBO  None  None  None
# 4       VSV  PHOENIX  JUMBO  None  None  None
# ...     ...      ...    ...   ...   ...   ...
# 154242  VSV  FLOREAL   None  None  None  None
# 154243  VSV  FLOREAL   None  None  None  None
# 154244  VSV  FLOREAL   None  None  None  None
# 154245  VSV  FLOREAL   None  None  None  None
# 154246  VSV  PHOENIX  JUMBO  None  None  None
#
# [154247 rows x 6 columns]

# %%
sales_df.sort_values(by='USER_ID', ascending=False)
# Out:
#         USER_ID    ORDER_ID   TIMESTAMP        ITEM_ID        LOCATION  \
# 20060    GRSP85     VSV5136  1639339200  GFI172185002H          GR VSV
# 48048    GRSP85     VSV3699  1606248000  GFI277241013I          GR VSV
# 47553    GRSP85     VSV3701  1606248000  GFI153058170I          GR VSV
# 109239   GRSP85     VSV5165  1640289600  GFP129277003J          GR VSV
# 120272   GRSP85     VSV5173  1641499200  GFI102185001J          GR VSV
# ...         ...         ...         ...            ...             ...
# 50511   GR10003  9903012144  1601668800  GFI172185001L  VSV CASCAVELLE
# 149717  GR10003  9903007147  1569628800  GFP103254022J  VSV CASCAVELLE
# 80352   GR10003  9903010172  1584561600  GFI102275001I  VSV CASCAVELLE
# 144648  GR10003  9903006213  1563494400  GFP081734001I  VSV CASCAVELLE
# 148276  GR10003  9903007167  1569628800  GFP081434001I  VSV CASCAVELLE
#
#        EVENT_TYPE  EVENT_VALUE
# 20060      bought          1.0
# 48048      bought          1.0
# ...

# %%
sales_df.sort_values(by=['USER_ID','ORDER_ID'], ascending=[False, True])
# Out:
#         USER_ID     ORDER_ID   TIMESTAMP        ITEM_ID        LOCATION  \
# 106855   GRSP85  71020005785  1608667200  GFI034056022I          GR VSV
# 5991     GRSP85  71021000034  1610049600  GFI172035004I          GR VSV
# 50449    GRSP85      VSV3641  1601496000  GFI156262001I          GR VSV
# 44769    GRSP85      VSV3676  1604520000  GFI153058170I          GR VSV
# 48048    GRSP85      VSV3699  1606248000  GFI277241013I          GR VSV
# ...         ...          ...         ...            ...             ...
# 147163  GR10003   9903006747  1566864000  GFP081434001I  VSV CASCAVELLE
# 149717  GR10003   9903007147  1569628800  GFP103254022J  VSV CASCAVELLE
# 148276  GR10003   9903007167  1569628800  GFP081434001I  VSV CASCAVELLE
# 80352   GR10003   9903010172  1584561600  GFI102275001I  VSV CASCAVELLE
# 50511   GR10003   9903012144  1601668800  GFI172185001L  VSV CASCAVELLE
#
#        EVENT_TYPE  EVENT_VALUE
# 106855     bought         -3.0
# 5991       bought         -2.0
# ...

# %%
sales_df.sort_index()
# Out:
#          USER_ID      ORDER_ID   TIMESTAMP        ITEM_ID           LOCATION  \
# 0        GR10015   99520090990  1644868800  GFI081434198I  VSV RIVIERE NOIRE
# 1       GR100607  999780046317  1645819200  GFI307337001J  VSV PHOENIX JUMBO
# 2       GR100607  999780046317  1645819200  GFI172185001L  VSV PHOENIX JUMBO
# 3       GR100607  999780046317  1645819200  GFI086772002K  VSV PHOENIX JUMBO
# 4       GR100611  999780046514  1646424000  GFI172668001J  VSV PHOENIX JUMBO
# ...          ...           ...         ...            ...                ...
# 154242   GR99590   99510083850  1642795200  GFI038077002L        VSV FLOREAL
# 154243   GR99590   99510083850  1642795200  GFI172683001J        VSV FLOREAL
# 154244   GR99590   99510083850  1642795200  GFI153263002I        VSV FLOREAL
# 154245   GR99590   99510083850  1642795200  GFI153263022I        VSV FLOREAL
# 154246   GR99602  999780045457  1642795200  GFI081707003I  VSV PHOENIX JUMBO
#
#        EVENT_TYPE  EVENT_VALUE
# ...

# %%
sales_df['EVENT_VALUE'].nlargest(10)
# Out:
# 16395     600.0
# 20750     600.0
# 60599     408.0
# 58130     372.0
# 58159     372.0
# 6728      240.0
# 18746     240.0
# 125284    240.0
# 143183    240.0
# 106155    208.0
# Name: EVENT_VALUE, dtype: float64

# %%
sales_df.dropna(axis='index', how='any', subset=['EVENT_VALUE'])
# Out:
#          USER_ID      ORDER_ID   TIMESTAMP        ITEM_ID           LOCATION  \
# 0        GR10015   99520090990  1644868800  GFI081434198I  VSV RIVIERE NOIRE
# 1       GR100607  999780046317  1645819200  GFI307337001J  VSV PHOENIX JUMBO
# 2       GR100607  999780046317  1645819200  GFI172185001L  VSV PHOENIX JUMBO
# 3       GR100607  999780046317  1645819200  GFI086772002K  VSV PHOENIX JUMBO
# 4       GR100611  999780046514  1646424000  GFI172668001J  VSV PHOENIX JUMBO
# ...          ...           ...         ...            ...                ...
# 154242   GR99590   99510083850  1642795200  GFI038077002L        VSV FLOREAL
# 154243   GR99590   99510083850  1642795200  GFI172683001J        VSV FLOREAL
# 154244   GR99590   99510083850  1642795200  GFI153263002I        VSV FLOREAL
# 154245   GR99590   99510083850  1642795200  GFI153263022I        VSV FLOREAL
# 154246   GR99602  999780045457  1642795200  GFI081707003I  VSV PHOENIX JUMBO
#
#        EVENT_TYPE  EVENT_VALUE
# ...

# %%
sales_df.dropna(axis='index', how='all', subset=['TIMESTAMP', 'EVENT_VALUE'])
# Out:
#          USER_ID      ORDER_ID   TIMESTAMP        ITEM_ID           LOCATION  \
# 0        GR10015   99520090990  1644868800  GFI081434198I  VSV RIVIERE NOIRE
# 1       GR100607  999780046317  1645819200  GFI307337001J  VSV PHOENIX JUMBO
# 2       GR100607  999780046317  1645819200  GFI172185001L  VSV PHOENIX JUMBO
# 3       GR100607  999780046317  1645819200  GFI086772002K  VSV PHOENIX JUMBO
# 4       GR100611  999780046514  1646424000  GFI172668001J  VSV PHOENIX JUMBO
# ...          ...           ...         ...            ...                ...
# 154242   GR99590   99510083850  1642795200  GFI038077002L        VSV FLOREAL
# 154243   GR99590   99510083850  1642795200  GFI172683001J        VSV FLOREAL
# 154244   GR99590   99510083850  1642795200  GFI153263002I        VSV FLOREAL
# 154245   GR99590   99510083850  1642795200  GFI153263022I        VSV FLOREAL
# 154246   GR99602  999780045457  1642795200  GFI081707003I  VSV PHOENIX JUMBO
#
#        EVENT_TYPE  EVENT_VALUE
# ...

# %%
sales_df.dtypes
# Out:
# USER_ID         object
# ORDER_ID        object
# TIMESTAMP        int64
# ITEM_ID         object
# LOCATION        object
# EVENT_TYPE      object
# EVENT_VALUE    float64
# dtype: object

# %%
sales_df['TIMESTAMP'] = sales_df['TIMESTAMP'].astype(float)

# %%
sales_df.dtypes
# Out:
# USER_ID         object
# ORDER_ID        object
# TIMESTAMP      float64
# ITEM_ID         object
# LOCATION        object
# EVENT_TYPE      object
# EVENT_VALUE    float64
# dtype: object

# %%
sales_df['EVENT_VALUE'].unique
# Out:
# <bound method Series.unique of 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 154242    6.0
# 154243    1.0
# 154244    2.0
# 154245    2.0
# 154246    1.0
# Name: EVENT_VALUE, Length: 154247, dtype: float64>

# %%
sales_df['EVENT_VALUE'].head(20)
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     2.0
# 7     6.0
# 8     1.0
# 9     2.0
# 10    1.0
# 11    1.0
# 12    2.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    2.0
# 18    1.0
# 19    1.0
# Name: EVENT_VALUE, dtype: float64

# %%
sales_df['EVENT_VALUE'].median()
# Out:
# 1.0

# %%
sales_df['EVENT_VALUE'].mean()
# Out:
# 2.2593761953230858

# %%
sales_df.describe()
# Out:
#           TIMESTAMP    EVENT_VALUE
# count  1.542470e+05  154247.000000
# mean   1.608711e+09       2.259376
# std    2.686430e+07       6.274903
# min    1.546301e+09    -372.000000
# 25%    1.592424e+09       1.000000
# 50%    1.611346e+09       1.000000
# 75%    1.631736e+09       2.000000
# max    1.647806e+09     600.000000

# %%
sales_df['EVENT_VALUE'].value_counts()
# Out:
# 1.0      99730
# 2.0      24289
# 3.0       7842
# 6.0       7201
# 4.0       4072
#          ...
# 104.0        1
# 152.0        1
# 102.0        1
# 74.0         1
# 56.0         1
# Name: EVENT_VALUE, Length: 147, dtype: int64

# %%
sales_df['EVENT_VALUE'].value_counts(normalize=True)
# Out:
# 1.0      0.646560
# 2.0      0.157468
# 3.0      0.050841
# 6.0      0.046685
# 4.0      0.026399
#            ...
# 104.0    0.000006
# 152.0    0.000006
# 102.0    0.000006
# 74.0     0.000006
# 56.0     0.000006
# Name: EVENT_VALUE, Length: 147, dtype: float64

# %%
sales_df['LOCATION'].value_counts()
# Out:
# VSV BEAU PLAN                               19250
# VSV LA CROISETTE                            16470
# VSV GRAND BAIE                              15468
# VSV BAGATELLE                               15424
# VSV FLACQ                                   15343
# VSV PHOENIX JUMBO                           14506
# VSV FLOREAL                                 11057
# VSV RIVIERE NOIRE                            9675
# VSV BEAU PLAN (MAHOGANY)                     9304
# VSV CASCAVELLE                               7637
# VSV BEAU VALLON                              6504
# VSV CAUDAN                                   3341
# VSV RODRIGUES SHOP                           3051
# COLORS BAGATELLE                             2628
# GR HOME DELIVERY                             1022
# PUBLIC BRADERIE                               785
# DISCOUNT SHOP FLOREAL                         673
# BRADERIE                                      577
# PHARMACIE                                     297
# ...

# %%
location_group = sales_df.groupby(['LOCATION'])

# %%
location_group.get_group('VSV BEAU PLAN (MAHOGANY)')
# Out:
#          USER_ID    ORDER_ID     TIMESTAMP        ITEM_ID  \
# 6        GR10068  9022010267  1.645733e+09  EFI189773001L
# 7        GR10068  9022010375  1.646078e+09  GFP038077002L
# 12      GR101578  9022009805  1.644610e+09  EFI142788008S
# 14      GR101578  9022010312  1.645819e+09  GFI153453026I
# 15      GR101578  9022009858  1.644782e+09  GFI153727015I
# ...          ...         ...           ...            ...
# 154231   GR94881  9022008788  1.642104e+09  GFI172037023H
# 154232   GR94881  9022008788  1.642104e+09  GFP287255002H
# 154233   GR94881  9022008743  1.641931e+09  EFI142788002S
# 154234   GR94882  9022009110  1.642795e+09  GFI287255003I
# 154241   GR98574  9022009019  1.642622e+09  GFI081433061I
#
#                         LOCATION EVENT_TYPE  EVENT_VALUE
# 6       VSV BEAU PLAN (MAHOGANY)     bought          2.0
# 7       VSV BEAU PLAN (MAHOGANY)     bought          6.0
# 12      VSV BEAU PLAN (MAHOGANY)     bought          2.0
# ...

# %%
location_group.get_group('VSV BEAU PLAN (MAHOGANY)')['ITEM_ID'].value_counts()
# Out:
# GFI172037023H    648
# GFI172037022J    282
# GFP287255002H    279
# GFI086772002K    240
# GFP173717003H    224
#                 ...
# GFP393689001I      1
# GFP393689003I      1
# GFP393693014I      1
# GFI081681140I      1
# EFI131108012X      1
# Name: ITEM_ID, Length: 291, dtype: int64

# %%
location_group['ITEM_ID'].value_counts().head(50)
# Out:
# LOCATION               ITEM_ID
# ARIANNE VITCHER        EFI160141001X      8
#                        EFI182099004X      8
# AUDREY PITCHEN         GFI038077002L      6
# BEATRICE DAWOO         EFI131108011X      2
#                        EFI350445001O      2
#                        EFI131108001X      1
#                        EFI131108002X      1
#                        EFI131108005X      1
#                        EFI131108015X      1
#                        EFI131108016X      1
#                        EFI350445003R      1
#                        EFI352449002O      1
# BEEKHARRY BRAMBHANAND  GFI038077002L      4
#                        GFI287255003I      4
#                        EFI142788002S      3
#                        EFI160141001X      3
#                        EFI190756002P      3
#                        EFI190756006P      3
#                        EFI182099004X      2
#                        EFI189771011J      2
#                        EFI190756003P      2
# ...

# %%
location_group['ITEM_ID'].value_counts().loc['VSV BEAU PLAN']
# Out:
# ITEM_ID
# GFI172037023H    807
# GFP287255002H    672
# GFP088038038H    588
# GFI172037022J    548
# GFP173717003H    500
#                 ...
# GFI287255001I      1
# GFI346631007E      1
# GFP065083012R      1
# GFP065083023O      1
# GFP393622008I      1
# Name: ITEM_ID, Length: 457, dtype: int64

# %%
location_group['EVENT_VALUE'].median()
# Out:
# LOCATION
# ARIANNE VITCHER                             40.0
# AUDREY PITCHEN                              60.0
# BEATRICE DAWOO                               2.0
# BEEKHARRY BRAMBHANAND                        1.0
# BRADERIE                                     1.0
# Bipasha KOWLESSUR                           12.0
# CHRISTIAN FOURNIER                          22.0
# COLORS BAGATELLE                             1.0
# Clinton cmarie                              40.0
# DAVID ROSETTE                               12.0
# DISCOUNT SHOP FLOREAL                        1.0
# DUTY PAID                                   12.0
# FEIZAL JEENALLY                              1.0
# FIRME                                        2.0
# GR HOME DELIVERY                             1.0
# GR VSV                                       1.0
# HANSRAJ SOOKUR                              10.0
# Inactive: COLORS AND SENSES LA CROISETTE     1.0
# JAUGUSTIN2                                   4.0
# ...

# %%
location_group['EVENT_VALUE'].agg(['mean', 'median'])
# Out:
#                                                mean  median
# LOCATION
# ARIANNE VITCHER                           30.000000    40.0
# AUDREY PITCHEN                            54.166667    60.0
# BEATRICE DAWOO                             2.727273     2.0
# BEEKHARRY BRAMBHANAND                      3.342857     1.0
# BRADERIE                                   2.658579     1.0
# Bipasha KOWLESSUR                         16.300000    12.0
# CHRISTIAN FOURNIER                        26.750000    22.0
# COLORS BAGATELLE                           1.022831     1.0
# Clinton cmarie                            27.846154    40.0
# DAVID ROSETTE                             29.068966    12.0
# DISCOUNT SHOP FLOREAL                      1.343239     1.0
# DUTY PAID                                 27.146341    12.0
# FEIZAL JEENALLY                            2.083333     1.0
# FIRME                                     17.057971     2.0
# ...

# %%
location_df = sales_df['LOCATION'].value_counts()
location_bought = location_group['EVENT_TYPE'].apply(lambda x: x.str.contains('bought').sum())

# %%
load_time = files.upload()
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
time_df = pd.read_csv(io.BytesIO(load_time['ETH_1h.csv']), parse_dates=['Date'], date_parser=d_parser)
# Out:
#      <input type="file" id="files-d3ca4ce2-5710-4511-a2af-f45d9c00529a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3ca4ce2-5710-4511-a2af-f45d9c00529a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ETH_1h.csv to ETH_1h.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
time_df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
time_df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
time_df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
time_df['DayOfWeek'] = time_df['Date'].dt.day_name()

# %%
time_df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
time_df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
time_df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
time_df['Date'].max() - time_df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (time_df['Date'] >= pd.to_datetime('2019-01-01')) & (time_df['Date'] < pd.to_datetime('2020-01-01'))
time_df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
time_df.set_index('Date', inplace=True)
time_df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
time_df['2019']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# ...

# %%
time_df['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
time_df['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.16559027777814

# %%
time_df['2020-01-01']['High'].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# 132.68

# %%
highs = time_df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
highs.plot()

# %%
time_df.resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
time_df.resample('W').agg({'Close': 'mean', 'High': 'max', 'Low': 'min', 'Volume': 'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %%
filt = (sales_df['LOCATION'] == 'VSV BEAU PLAN')
beau_df = sales_df.loc[filt]
beau_df.head()
# Out:
#       USER_ID     ORDER_ID     TIMESTAMP        ITEM_ID       LOCATION  \
# 3274  GR61113  99600223552  1.646251e+09  GFI081433061I  VSV BEAU PLAN
# 4324  GR42798  99600223283  1.623182e+09  GFP348454002I  VSV BEAU PLAN
# 4326   GR3040  99600221515  1.617739e+09  GFI286260003I  VSV BEAU PLAN
# 4329  GR28073  99600221567  1.617912e+09  GFI086772002K  VSV BEAU PLAN
# 4338   GR3041  99600221580  1.617912e+09  GFI081004025I  VSV BEAU PLAN
#
#      EVENT_TYPE  EVENT_VALUE
# 3274     bought          1.0
# 4324     bought          1.0
# 4326     bought          4.0
# 4329     bought          1.0
# 4338     bought          2.0

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/data/output.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  beau_df.to_csv(f)

# %%
path = '/content/drive/My Drive/data/output1.tsv'
with open(path, 'w', encoding = 'utf-8-sig') as g:
  beau_df.to_csv(g, sep='\t')

# %%
path = '/content/drive/My Drive/data/output2.xlsx'
beau_df.to_excel(path)

# %%
test_df = pd.read_excel(path, index_col='USER_ID')

# %%
test_df.head()
# Out:
#          Unnamed: 0     ORDER_ID   TIMESTAMP        ITEM_ID       LOCATION  \
# USER_ID
# GR61113        3274  99600223552  1646251200  GFI081433061I  VSV BEAU PLAN
# GR42798        4324  99600223283  1623182400  GFP348454002I  VSV BEAU PLAN
# GR3040         4326  99600221515  1617739200  GFI286260003I  VSV BEAU PLAN
# GR28073        4329  99600221567  1617912000  GFI086772002K  VSV BEAU PLAN
# GR3041         4338  99600221580  1617912000  GFI081004025I  VSV BEAU PLAN
#
#         EVENT_TYPE  EVENT_VALUE
# USER_ID
# GR61113     bought            1
# GR42798     bought            1
# GR3040      bought            4
# GR28073     bought            1
# GR3041      bought            2

# %%
test_df.drop(['Unnamed: 0'], axis='columns')
# Out:
#              ORDER_ID   TIMESTAMP        ITEM_ID       LOCATION EVENT_TYPE  \
# USER_ID
# GR61113   99600223552  1646251200  GFI081433061I  VSV BEAU PLAN     bought
# GR42798   99600223283  1623182400  GFP348454002I  VSV BEAU PLAN     bought
# GR3040    99600221515  1617739200  GFI286260003I  VSV BEAU PLAN     bought
# GR28073   99600221567  1617912000  GFI086772002K  VSV BEAU PLAN     bought
# GR3041    99600221580  1617912000  GFI081004025I  VSV BEAU PLAN     bought
# ...               ...         ...            ...            ...        ...
# GR94572   99600204050  1572393600  GFI172037023H  VSV BEAU PLAN     bought
# GR111657  99600203757  1571702400  GFP173717004G  VSV BEAU PLAN     bought
# GR94835   99600203642  1571270400  GFP173717004G  VSV BEAU PLAN     bought
# GR112637  99600203927  1571961600  GFP173606004G  VSV BEAU PLAN     bought
# GR76491   99600203505  1570752000  GFP081742001I  VSV BEAU PLAN     bought
#
#           EVENT_VALUE
# USER_ID
# GR61113             1
# ...

# %%
beau_df.to_json('/content/drive/My Drive/data/output3.json', orient='records', lines=True)

# %%
test_df = pd.read_json('/content/drive/My Drive/data/output3.json', orient='records', lines=True)

# %%
test_df.head()
# Out:
#    USER_ID     ORDER_ID           TIMESTAMP        ITEM_ID       LOCATION  \
# 0  GR61113  99600223552 2022-03-02 20:00:00  GFI081433061I  VSV BEAU PLAN
# 1  GR42798  99600223283 2021-06-08 20:00:00  GFP348454002I  VSV BEAU PLAN
# 2   GR3040  99600221515 2021-04-06 20:00:00  GFI286260003I  VSV BEAU PLAN
# 3  GR28073  99600221567 2021-04-08 20:00:00  GFI086772002K  VSV BEAU PLAN
# 4   GR3041  99600221580 2021-04-08 20:00:00  GFI081004025I  VSV BEAU PLAN
#
#   EVENT_TYPE  EVENT_VALUE
# 0     bought            1
# 1     bought            1
# 2     bought            4
# 3     bought            1
# 4     bought            2
